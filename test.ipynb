# %%
import pandas as pd
import numpy as np


def load_data(url):
    return pd.read_csv(url)


def clean_tiobe_top_20(df):
    return (
        df
        .drop(columns=['Unnamed: 0', 'Sep 2021', 'Programming Language'])
        .rename(columns={'Sep 2022': 'Rank 2022',
                         'Programming Language.1': 'Programming Language'})
        .iloc[:, [1, 0, 2]]
    )


def clean_tiobe_history(df):
    return (
        df
        .drop(columns=['Unnamed: 0'])
        .set_index('Programming Language')
        .transpose()
        .rename_axis('', axis='columns')
        .reset_index()
        .rename(columns={'index': 'year'})
        .melt(id_vars='year')
        .rename(columns={'value': 'rank', '': 'language'})
        .sort_values(by=['year', 'rank'])
        .assign(rank=lambda df: df['rank'].replace({'-': np.nan}).astype('float'))
        .query("~language.isin(['Pascal', 'Visual Basic', '(Visual) Basic', 'Prolog'])", engine='python')
    )

tiobe_history_url = "https://raw.githubusercontent.com/mwiemers/python_workshops_app/main/tiobe_history.csv"

df = load_data(tiobe_history_url)

df
# Out:
#     Unnamed: 0 Programming Language 2022 2017 2012 2007 2002 1997 1992 1987
# 0            1               Python    1    5    8    7   12   28    -    -
# 1            2                    C    2    2    1    2    2    1    1    1
# 2            3                 Java    3    1    2    1    1   16    -    -
# 3            4                  C++    4    3    3    3    3    2    2    6
# 4            5                   C#    5    4    4    8   14    -    -    -
# 5            6         Visual Basic    6   14    -    -    -    -    -    -
# 6            7           JavaScript    7    8   10    9    8   24    -    -
# 7            8    Assembly language    8   10    -    -    -    -    -    -
# 8            9                  SQL    9    -    -    -    7    -    -    -
# 9           10                  PHP   10    7    6    5    6    -    -    -
# 10          11               Prolog   24   32   33   27   17   21   12    3
# 11          12                 Lisp   33   31   13   16   13   10    4    2
# 12          13               Pascal  270  114   16   22   99    9    3    5
# 13          14       (Visual) Basic    -    -    7    4    4    3    6    4

# %%
df = clean_tiobe_history(df)

df
